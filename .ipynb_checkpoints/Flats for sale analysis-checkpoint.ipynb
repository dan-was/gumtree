# %% [markdown]
# # Gumtree apartment sale price analysis for Warsaw, Poland

# %% [markdown]
# The purpose of this analysis is to construct price prediction models for all city districts. Four model types: linear regression, random forest regression, extra trees regression and gradient boosting regression from sckitlearn package have been used. $ R^2 $ metric was used for model assessment.

# %%
from ads_tools import Ads
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set()
sns.set_context('paper')

# %% [markdown]
# Load ads data from JSON file by initializing Ads class

# %%
flats_sale = Ads('flat_sale')

# %% [markdown]
# Filter out outlayers and transform the dataset into a pandas DataFrame

# %%
flats_sale.filter_and_transform_to_df(min_price=30000.00, max_price=5000000.0,size_limit=300.0)
# Out:
# Dataset transfromed to a DataFrame and formatted
# NA values removed from columns: 'price', 'date'

# %%
print(flats_sale)
# Out:
# Ads dataset class. Number of observations: 174866, Number of variables: 13

# %%
dataset = flats_sale.filtered_data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 174866 entries, 1001294070520910468328209 to 1002186585010910469292709
# Data columns (total 13 columns):
# adress          174550 non-null object
# price           174866 non-null float64
# date            174866 non-null datetime64[ns]
# n_rooms         174373 non-null float64
# n_bath          67655 non-null float64
# location        174866 non-null object
# advertiser      173600 non-null object
# desc            174866 non-null object
# parking         54866 non-null object
# type            174866 non-null object
# street_regex    75839 non-null object
# size_m2         174866 non-null float64
# url             174866 non-null object
# dtypes: datetime64[ns](1), float64(4), object(8)
# memory usage: 18.7+ MB

# %%
dataset.head(2)
# Out:
#                                     adress     price       date  n_rooms  \
# 1001294070520910468328209        Wrzeciono  305000.0 2017-09-06      2.0
# 1001294070590910468328209  Josepha Conrada  390000.0 2017-09-26      3.0
#
#                            n_bath location advertiser  \
# 1001294070520910468328209     NaN  Bielany     agency
# 1001294070590910468328209     NaN  Bielany     agency
#
#                                                                         desc  \
# 1001294070520910468328209  BIELANY – ładny rozkład mieszkania – 2pok – 47...
# 1001294070590910468328209  Bielany – 3 pokoje 60m – po remoncie do wejści...
#
#                           parking        type street_regex  size_m2  \
# 1001294070520910468328209    None  Mieszkanie         None     47.0
# 1001294070590910468328209    None  Mieszkanie         None     60.0
#
#                                                                          url
# 1001294070520910468328209  https://www.gumtree.pl/a-mieszkania-i-domy-spr...
# 1001294070590910468328209  https://www.gumtree.pl/a-mieszkania-i-domy-spr...

# %%
dataset.reset_index(inplace=True)

# %% [markdown]
# Celect columns that will be used in the analysis:

# %%
cols = ['price','advertiser','n_rooms','n_bath','location','size_m2','parking']
dataset = dataset[cols]

# %%
dataset.head()
# Out:
#       price advertiser  n_rooms  n_bath location  size_m2 parking
# 0  305000.0     agency      2.0     NaN  Bielany     47.0    None
# 1  390000.0     agency      3.0     NaN  Bielany     60.0    None
# 2  397000.0     agency      3.0     NaN  Mokotow     54.0    None
# 3  341000.0     agency      3.0     NaN  Bielany     51.0    None
# 4  283000.0     agency      2.0     NaN  Bielany     35.0    None

# %%
plt.figure(figsize=(10,6))
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)
plt.show()

# %% [markdown]
# Replace missing values with default values:

# %%
values = {'n_bath': 1.0, 'parking': 'no'}
dataset = dataset.fillna(value=values)

# %%
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)
plt.show()

# %%
dataset.dropna(inplace=True)

# %% [markdown]
# Unique values of variables:

# %%
for col in dataset:
    if col not in ['price', 'size_m2']:
        print("{}: {}".format(col, dataset[col].unique()))
        print("")
# Out:
# advertiser: ['agency' 'owner']
#
# n_rooms: [ 2.  3.  5.  1.  4.  6.]
#
# n_bath: [ 1.  2.  3.  4.]
#
# location: ['Bielany' 'Mokotow' 'Zoliborz' 'Bemowo' 'Praga Poludnie' 'Ochota' 'Wawer'
#  'Bialoleka' 'Praga Polnoc' 'Wilanow' 'Srodmiescie' 'Ursynow' 'Wola'
#  'Ursus' 'Targowek' 'Wesola' 'Wlochy' 'Rembertow']
#
# parking: ['no' 'garage' 'street' 'basement']

# %% [markdown]
# Change price units to thousand PLN and calculate price per square meter

# %%
dataset['price'] = dataset['price']/1000.0
dataset['price_m2'] = dataset['price']/dataset['size_m2']

# %%
dataset.head(2)
# Out:
#    price advertiser  n_rooms  n_bath location  size_m2 parking  price_m2
# 0  305.0     agency      2.0     1.0  Bielany     47.0      no  6.489362
# 1  390.0     agency      3.0     1.0  Bielany     60.0      no  6.500000

# %% [markdown]
# Remove ads with price per square meter higher than PLN 25k

# %%
dataset = dataset[dataset['price_m2']<25.0]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172805 entries, 0 to 174865
# Data columns (total 8 columns):
# price         172805 non-null float64
# advertiser    172805 non-null object
# n_rooms       172805 non-null float64
# n_bath        172805 non-null float64
# location      172805 non-null object
# size_m2       172805 non-null float64
# parking       172805 non-null object
# price_m2      172805 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 11.9+ MB

# %%
sns.pairplot(dataset,hue='advertiser', diag_kws=dict(bins=20))
plt.show()

# %% [markdown]
# We can see that majority of ads were added by agency and not directyly by owners:

# %%
g = sns.FacetGrid(dataset,col='n_rooms',row='advertiser')
g.map(plt.hist,'price',bins=50)

# %%
sns.countplot(dataset['advertiser'])

# %% [markdown]
# Vast majority of apratments have wither two or three rooms:

# %%
ax = sns.countplot(x='n_rooms',data=dataset)
ax.set(xlabel='Number of rooms', ylabel='Number of ads', title='Number of rooms in a flat')
plt.show()

# %%
ax = sns.countplot(x='n_bath',data=dataset)
ax.set(xlabel='Number of bathrooms', ylabel='Number of ads', title='Number of bathrooms in a flat')
plt.show()

# %%
plt.figure(figsize=(12,6))
ranks = dataset.groupby('location')['price_m2'].count().sort_values()[::-1].index
ax = sns.countplot(y='location',data=dataset,order=ranks)
ax.set(xlabel='Number of advertisements', ylabel='City district', title='Number of flats offered for sale in districts')
plt.show()

# %%
plt.figure(figsize=(10,6))
ranks = dataset.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=dataset, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel='Total price (PLN)', ylabel='City district', title='Price distribution in districts')
plt.show()

# %%
plt.figure(figsize=(10,6))
ranks = dataset.groupby('location')['price_m2'].median().sort_values()[::-1].index
ax = sns.boxplot(data=dataset, y='location',x='price_m2',fliersize=2, order=ranks)
ax.set(xlabel="Price ('000 PLN per 1 m^2)", ylabel='City district', 
       title='Price distribution in districts - one square meter')
plt.show()

# %%
plt.figure(figsize=(10,4))
ax = sns.boxplot(data=dataset, y='n_rooms',x='price',fliersize=2,orient='h')
ax.set(xlabel='Total price (PLN)', ylabel='Number of rooms', title='Price distribution per number of rooms')
plt.show()

# %%
plt.figure(figsize=(10,2))
ax = sns.boxplot(data=dataset, y='n_bath',x='price',fliersize=2,orient='h')
ax.set(xlabel='Total price (PLN)', ylabel='Number of bathrooms', title='Price distribution per number of bathrooms')
plt.show()

# %% [markdown]
# # Two-room apartments analysis

# %%
two_room = dataset[(dataset['n_rooms']==2.0) & (dataset['price']<1200.00)]

# %%
two_room.describe()
# Out:
#               price  n_rooms        n_bath       size_m2      price_m2
# count  64562.000000  64562.0  64562.000000  64562.000000  64562.000000
# mean     419.108693      2.0      1.007342     47.894288      8.729284
# std      141.735371      0.0      0.100688      9.700962      2.138306
# min       32.900000      2.0      1.000000     21.000000      0.692308
# 25%      325.000000      2.0      1.000000     41.000000      7.250000
# 50%      389.000000      2.0      1.000000     47.000000      8.413839
# 75%      485.000000      2.0      1.000000     54.000000      9.785714
# max     1199.900000      2.0      4.000000    138.000000     24.500000

# %%
plt.figure(figsize=(10,6))
ranks = two_room.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=two_room, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel="Total price ('000 PLN)", ylabel='City district', title='Price distribution in districts (two-room flats)')
plt.show()

# %%
plt.figure(figsize=(10,6))
ranks = two_room.groupby('location')['price_m2'].median().sort_values()[::-1].index
ax = sns.boxplot(data=two_room, y='location',x='price_m2',fliersize=2, order=ranks)
ax.set(xlabel="Price ('000 PLN per 1 m^2)", ylabel='City district', 
       title='Price distribution in districts - one square meter (two-room flats)')
plt.show()

# %% [markdown]
# # Three-room apartments analysis

# %%
three_room = dataset[(dataset['n_rooms']==3.0) & (dataset['price']<1500.00)]

# %%
three_room.describe()
# Out:
#               price  n_rooms        n_bath       size_m2      price_m2
# count  66911.000000  66911.0  66911.000000  66911.000000  66911.000000
# mean     570.864979      3.0      1.062441     67.719149      8.333944
# std      218.606105      0.0      0.244904     15.463971      2.043271
# min       32.500000      3.0      1.000000     29.000000      0.532468
# 25%      418.666000      3.0      1.000000     57.000000      6.957603
# 50%      499.949000      3.0      1.000000     65.000000      7.934783
# 75%      675.000000      3.0      1.000000     76.000000      9.399167
# max     1499.000000      3.0      4.000000    250.000000     21.949153

# %%
plt.figure(figsize=(10,6))
ranks = three_room.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=three_room, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel="Total price ('000 PLN)", ylabel='City district', title='Price distribution in districts (three-room flats)')
plt.show()

# %% [markdown]
# # Model construction

# %% [markdown]
# Four price prediction model types have been estimated and assessed below. The first one (linear model for Mokotow district) was explained in more detail first.

# %% [markdown]
# ## Linear regression model

# %% [markdown]
# First we create a subset of data for one district.

# %%
district_data = dataset[dataset['location'] == 'Mokotow']

# %% [markdown]
# Then we remove unused columns forom the dataset

# %%
district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]

# %% [markdown]
# Check correlations between variables

# %%
district_data.corr()
# Out:
#             price   n_rooms   size_m2    n_bath
# price    1.000000  0.576651  0.857946  0.223163
# n_rooms  0.576651  1.000000  0.751864  0.244554
# size_m2  0.857946  0.751864  1.000000  0.270847
# n_bath   0.223163  0.244554  0.270847  1.000000

# %% [markdown]
# Next, we create dummy variables for parking place type with "no_parking" as the reference variable which is dropped to avoid multicollinearity

# %%
parking = pd.get_dummies(district_data['parking'],prefix='parking')
model_dataset = pd.concat([district_data,parking],axis=1)
model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
model_dataset.describe()
# Out:
#               price       n_rooms       size_m2        n_bath  \
# count  26899.000000  26899.000000  26899.000000  26899.000000
# mean     663.395974      2.655154     66.824938      1.061973
# std      437.625601      0.873414     30.082173      0.267845
# min       47.000000      1.000000     13.000000      1.000000
# 25%      418.003000      2.000000     47.000000      1.000000
# 50%      540.000000      3.000000     59.000000      1.000000
# 75%      760.227500      3.000000     80.000000      1.000000
# max     4900.000000      6.000000    294.000000      4.000000
#
#        parking_basement  parking_garage  parking_street
# count      26899.000000    26899.000000    26899.000000
# mean           0.052604        0.069705        0.174059
# std            0.223246        0.254654        0.379167
# min            0.000000        0.000000        0.000000
# 25%            0.000000        0.000000        0.000000
# 50%            0.000000        0.000000        0.000000
# 75%            0.000000        0.000000        0.000000
# max            1.000000        1.000000        1.000000

# %% [markdown]
# Create a matrix of exogenous variables $X$ and dependant (target) variable vector $y$

# %%
X = model_dataset.drop('price',axis=1)
y = model_dataset['price']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Split the data into training and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Estimate parameters of linear regression model

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
coeffs = pd.DataFrame(data=lm.coef_,index=X.columns, columns=['Coefficient'])
coeffs.sort_values(by='Coefficient',inplace=True)

# %%
plt.figure(figsize=(3,3))
sns.barplot(data=coeffs.transpose(),orient='h',color='lightblue')
plt.show()

# %%
pred = lm.predict(X_test)

# %% [markdown]
# The model explains around 75% of the target variables's variance

# %%
lm.score(X_test,y_test)
# Out:
# 0.75054571028620376

# %% [markdown]
# ## Models for all districts

# %%
districts = list(dataset['location'].unique())

# %%
districts
# Out:
# ['Bielany',
#  'Mokotow',
#  'Zoliborz',
#  'Bemowo',
#  'Praga Poludnie',
#  'Ochota',
#  'Wawer',
#  'Bialoleka',
#  'Praga Polnoc',
#  'Wilanow',
#  'Srodmiescie',
#  'Ursynow',
#  'Wola',
#  'Ursus',
#  'Targowek',
#  'Wesola',
#  'Wlochy',
#  'Rembertow']

# %%
r2_dict = dict()
model_dict = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    lm = LinearRegression()
    lm.fit(X_train,y_train)
    coeffs = pd.DataFrame(data=lm.coef_,index=X.columns, columns=['Coefficient'])
    coeffs.sort_values(by='Coefficient',inplace=True)
    r2_dict[district] = lm.score(X_test,y_test)
    model_dict[district] = coeffs

# %%
r2 = pd.DataFrame(pd.Series(r2_dict),columns=['R^2 Score'])

# %%
regression_parameters = pd.DataFrame(pd.Series(model_dict))
regression_parameters.loc['Bemowo'][0]
# Out:
#                   Coefficient
# parking_street     -44.878865
# n_rooms            -26.699885
# size_m2              7.869292
# parking_garage       8.350160
# n_bath              26.810261
# parking_basement    38.910723

# %% [markdown]
# Random forest regression:

# %%
r2_dict_rf = dict()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    forest_reg = RandomForestRegressor()
    forest_reg.fit(X_train, y_train)
    r2_dict_rf[district] = forest_reg.score(X_test,y_test)

# %%
r2_rf = pd.DataFrame(pd.Series(r2_dict_rf),columns=['R^2 Score_random_forest'])

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# Extra trees regression:

# %%
r2_dict_extra_tree = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    forest_reg_e = ExtraTreesRegressor()
    forest_reg_e.fit(X_train, y_train)
    r2_dict_extra_tree[district] = forest_reg_e.score(X_test,y_test)

# %%
r2_rf_extra = pd.DataFrame(pd.Series(r2_dict_extra_tree),columns=['R^2 Score_extra_trees'])

# %% [markdown]
# Gradient Boosting regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
r2_dict_gradient_boost = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    gradient_boosting_reg = GradientBoostingRegressor()
    gradient_boosting_reg.fit(X_train, y_train)
    r2_dict_gradient_boost[district] = gradient_boosting_reg.score(X_test,y_test)

# %%
r2_gradient_boost = pd.DataFrame(pd.Series(r2_dict_gradient_boost),columns=['R^2 Score_GB'])

# %% [markdown]
# Create a dataframe of $R^2$ scores for all models

# %%
results = pd.concat([r2, r2_rf, r2_rf_extra, r2_gradient_boost], axis=1)

# %%
results
# Out:
#                 R^2 Score  R^2 Score_random_forest  R^2 Score_extra_trees  \
# Bemowo           0.691992                 0.898381               0.887579
# Bialoleka        0.781878                 0.887486               0.904954
# Bielany          0.752451                 0.929311               0.915682
# Mokotow          0.759332                 0.908347               0.909261
# Ochota           0.848202                 0.954984               0.939099
# Praga Polnoc     0.790524                 0.894523               0.848977
# Praga Poludnie   0.746142                 0.894918               0.902538
# Rembertow        0.754755                 0.815218               0.828758
# Srodmiescie      0.754004                 0.902918               0.900987
# Targowek         0.836176                 0.909821               0.924417
# Ursus            0.835279                 0.928859               0.906036
# Ursynow          0.801701                 0.940421               0.934359
# Wawer            0.689860                 0.882688               0.882355
# Wesola           0.678607                 0.954395               0.926039
# Wilanow          0.691519                 0.869040               0.947590
# Wlochy           0.689246                 0.923914               0.950018
# Wola             0.788229                 0.917930               0.916559
# Zoliborz         0.823062                 0.943406               0.960058
#
#                 R^2 Score_GB
# Bemowo              0.847000
# Bialoleka           0.857594
# Bielany             0.885173
# Mokotow             0.844859
# Ochota              0.906804
# Praga Polnoc        0.849275
# Praga Poludnie      0.846977
# Rembertow           0.836547
# Srodmiescie         0.817810
# Targowek            0.890611
# Ursus               0.886178
# Ursynow             0.891049
# Wawer               0.911657
# Wesola              0.913382
# Wilanow             0.889479
# Wlochy              0.831342
# Wola                0.878828
# Zoliborz            0.920143

# %%
plt.figure(figsize=(7,4))
sns.heatmap(results, cmap='coolwarm', annot=True)
plt.show()

# %%
results.mean().plot(kind='bar')
