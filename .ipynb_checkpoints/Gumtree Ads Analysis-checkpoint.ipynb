# %%
from ads_tools import Ads
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
rooms = Ads('flat')

# %%
rooms.filter_and_transform_to_df()
# Out:
# Dataset transformed to a DataFrame
# Column names changed
# Adress format changed
# Prices format changed
# Dates format changed
# Advertiser format changed
# Number of rooms format changed
# Number of bathrooms format changed
# Location format changed
# Description format changed
# Smoking preference format changed
# Parking data format changed
# Animals allowed format changed
# Type format changed
# Size m^2 format changed
# NA values removed from columns: 'price', 'date'

# %%
dataset = rooms.filtered_data

# %%
dataset.head()
# Out:
#                                          adress   price coords       date  \
# 1001294596470910467972909              Giełdowa  3200.0    NaN 2017-08-13
# 1001295618690910467972909          Biały Kamień  4000.0    NaN 2017-08-09
# 1001295631820910467972909  Jana Pawła Woronicza  4500.0    NaN 2017-07-30
# 1001297367450910467972909              Puławska  3200.0    NaN 2017-07-28
# 1001297456900910467972909               Mokotów  3000.0    NaN 2017-08-04
#
#                           advertiser available  n_rooms  n_bath location  \
# 1001294596470910467972909     agency      None      2.0     1.0     Wola
# 1001295618690910467972909     agency      None      2.0     1.0  Mokotow
# 1001295631820910467972909     agency      None      2.0     1.0  Mokotow
# 1001297367450910467972909     agency      None      2.0     1.0  Mokotow
# 1001297456900910467972909     agency      None      2.0     1.0  Mokotow
#
#                                                                         desc  \
# ...

# %%
dataset.reset_index(inplace=True)

# %%
cols = ['price','advertiser','n_rooms','n_bath','location','smoking','size_m2','parking','animals']
dataset = dataset[cols]

# %%
dataset.head()
# Out:
#     price advertiser  n_rooms  n_bath location smoking  size_m2 parking  \
# 0  3200.0     agency      2.0     1.0     Wola    None     48.0   Garaż
# 1  4000.0     agency      2.0     1.0  Mokotow    None     60.0   Garaż
# 2  4500.0     agency      2.0     1.0  Mokotow    None     60.0   Garaż
# 3  3200.0     agency      2.0     1.0  Mokotow    None     56.0   Garaż
# 4  3000.0     agency      2.0     1.0  Mokotow    None     54.0   Garaż
#
#   animals
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
sns.set_context('paper')

# %%
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)

# %%
cols = ['price','advertiser','n_rooms','location','size_m2']
dataset = dataset[cols]
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)

# %%
dataset.dropna(inplace=True)

# %%
sns.pairplot(dataset,hue='advertiser')

# %%
sns.countplot(x='n_rooms',data=dataset)

# %%
sns.countplot(y='location',data=dataset)

# %%
sns.jointplot('size_m2','price',dataset,kind='hex')

# %%
sns.boxplot(data=dataset, y='location',x='price',fliersize=2)

# %%
sns.boxplot(data=dataset,y='advertiser',x='price')

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(dataset['location'])

# %%
enc
# Out:
# OneHotEncoder(categorical_features='all', dtype=<class 'numpy.float64'>,
#        handle_unknown='error',
#        n_values=0                  Wola
# 1               Mokotow
# 2               Mokotow
# 3               Mokotow
# 4               Mokotow
# 5               Mokotow
# 6           Srodmiescie
# 7           Srodmiescie
# 8           Srodmiescie
# 9               Mokotow
# 10              Wilanow
# 11              Wilanow
# 12 ...3764            Bemowo
# 53765              Wola
# 53766           Mokotow
# Name: location, dtype: object,
#        sparse=True)
