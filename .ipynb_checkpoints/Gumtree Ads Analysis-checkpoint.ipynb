# %%
from ads_tools import Ads
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline
sns.set()
sns.set_context('paper')

# %%
flats = Ads('flat')

# %%
flats.filter_and_transform_to_df(min_price=300.00, max_price=15000.0, size_limit=300.0)
# Out:
# Dataset transfromed to a DataFrame and formatted
# NA values removed from columns: 'price', 'date'

# %%
print(flats)
# Out:
# Ads dataset class. Number of observations: 155345, Number of variables: 17

# %%
dataset = flats.filtered_data

# %%
dataset.head()
# Out:
#                                          adress   price coords       date  \
# 1001294596470910467972909              Giełdowa  3200.0    NaN 2017-08-13
# 1001295618690910467972909          Biały Kamień  4000.0    NaN 2017-08-09
# 1001295631820910467972909  Jana Pawła Woronicza  4500.0    NaN 2017-07-30
# 1001297367450910467972909              Puławska  3200.0    NaN 2017-07-28
# 1001297456900910467972909               Mokotów  3000.0    NaN 2017-08-04
#
#                           advertiser available  n_rooms  n_bath location  \
# 1001294596470910467972909     agency      None      2.0     1.0     Wola
# 1001295618690910467972909     agency      None      2.0     1.0  Mokotow
# 1001295631820910467972909     agency      None      2.0     1.0  Mokotow
# 1001297367450910467972909     agency      None      2.0     1.0  Mokotow
# 1001297456900910467972909     agency      None      2.0     1.0  Mokotow
#
#                                                                         desc  \
# 1001294596470910467972909  NOWOCZESNE i ATRAKCYJNE DWUPOKOJOWE mieszkanie...
# 1001295618690910467972909  ATRAKCYJNY, nowocześnie urządzony apartament n...
# 1001295631820910467972909  DWUPOZIOMOWE, NOWE mieszkanie typu SOFT LOFT u...
# 1001297367450910467972909  Umeblowane, wykończone w wysokim standardzie m...
# 1001297456900910467972909  W pełni umeblowane mieszkanie o powierzchni 54...
#
#                           smoking parking animals        type  \
# 1001294596470910467972909    None  garage    None  Mieszkanie
# 1001295618690910467972909    None  garage    None  Mieszkanie
# 1001295631820910467972909    None  garage    None  Mieszkanie
# 1001297367450910467972909    None  garage    None  Mieszkanie
# 1001297456900910467972909    None  garage    None  Mieszkanie
#
#                                             street_regex  size_m2  \
# 1001294596470910467972909         [Towarowej, Giełdowej]     48.0
# 1001295618690910467972909                           None     60.0
# 1001295631820910467972909                           None     60.0
# 1001297367450910467972909                           None     56.0
# 1001297456900910467972909  [zabaw, zabaw, [zabaw, oraz]]     54.0
#
#                                                                          url
# 1001294596470910467972909  https://www.gumtree.pl/a-mieszkania-i-domy-do-...
# 1001295618690910467972909  https://www.gumtree.pl/a-mieszkania-i-domy-do-...
# 1001295631820910467972909  https://www.gumtree.pl/a-mieszkania-i-domy-do-...
# 1001297367450910467972909  https://www.gumtree.pl/a-mieszkania-i-domy-do-...
# 1001297456900910467972909  https://www.gumtree.pl/a-mieszkania-i-domy-do-...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 155345 entries, 1001294596470910467972909 to 1002181682200911304300609
# Data columns (total 17 columns):
# adress          154876 non-null object
# price           155345 non-null float64
# coords          776 non-null object
# date            155345 non-null datetime64[ns]
# advertiser      154084 non-null object
# available       57214 non-null object
# n_rooms         154982 non-null float64
# n_bath          74490 non-null float64
# location        155345 non-null object
# desc            155345 non-null object
# smoking         18651 non-null object
# parking         64006 non-null object
# animals         25799 non-null object
# type            155345 non-null object
# street_regex    99355 non-null object
# size_m2         155345 non-null float64
# url             155345 non-null object
# dtypes: datetime64[ns](1), float64(4), object(12)
# memory usage: 21.3+ MB

# %%
dataset.describe()
# Out:
# C:\Users\Daniel\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#                price        n_rooms        n_bath        size_m2
# count  155345.000000  154982.000000  74490.000000  155345.000000
# mean     3360.925096       2.356145      1.126675      61.266137
# std      1675.887684       0.827297      0.349036      27.484132
# min       330.000000       1.000000      1.000000       1.000000
# 25%      2500.000000            NaN           NaN      44.000000
# 50%      2900.000000            NaN           NaN      54.000000
# 75%      3700.000000            NaN           NaN      70.000000
# max     14950.000000       6.000000      4.000000     295.000000

# %%
dataset.reset_index(inplace=True)

# %%
cols = ['price','advertiser','n_rooms','n_bath','location','smoking','size_m2','parking','animals']
dataset = dataset[cols]

# %%
dataset.head()
# Out:
#     price advertiser  n_rooms  n_bath location smoking  size_m2 parking  \
# 0  3200.0     agency      2.0     1.0     Wola    None     48.0  garage
# 1  4000.0     agency      2.0     1.0  Mokotow    None     60.0  garage
# 2  4500.0     agency      2.0     1.0  Mokotow    None     60.0  garage
# 3  3200.0     agency      2.0     1.0  Mokotow    None     56.0  garage
# 4  3000.0     agency      2.0     1.0  Mokotow    None     54.0  garage
#
#   animals
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)
plt.show()

# %%
values = {'n_bath': 1.0, 'parking': 'no'}
dataset = dataset.fillna(value=values)

cols = ['price','advertiser','n_rooms','n_bath','location','size_m2','parking']
dataset = dataset[cols]
sns.heatmap(dataset.isnull(),cbar=False,yticklabels=False)
plt.show()

# %%
dataset.dropna(inplace=True)

# %%
dataset['price_m2'] = dataset['price']/dataset['size_m2']

# %%
dataset = dataset[dataset['price_m2']<450.0]

# %%
dataset.head(2)
# Out:
#     price advertiser  n_rooms  n_bath location  size_m2 parking   price_m2
# 0  3200.0     agency      2.0     1.0     Wola     48.0  garage  66.666667
# 1  4000.0     agency      2.0     1.0  Mokotow     60.0  garage  66.666667

# %%
sns.pairplot(dataset,hue='advertiser', diag_kws=dict(bins=20))
plt.show()

# %%
g = sns.FacetGrid(dataset,col='n_rooms',row='advertiser')
g.map(plt.hist,'price',bins=50)

# %%
sns.countplot(dataset['advertiser'])

# %%
ax = sns.countplot(x='n_rooms',data=dataset)
ax.set(xlabel='Number of rooms', ylabel='Number of ads', title='Number of rooms in a flat')
plt.show()

# %%
ranks = dataset.groupby('location')['price_m2'].count().sort_values()[::-1].index
ax = sns.countplot(y='location',data=dataset,order=ranks)
ax.set(xlabel='Number of advertisements', ylabel='City district', title='Number of flats offered for rent in districts')
plt.show()

# %%
ax = sns.countplot(x='n_bath',data=dataset)
ax.set(xlabel='Number of bathrooms', ylabel='Number of ads', title='Number of bathrooms in a flat')
plt.show()

# %%
ranks = dataset.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=dataset, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel='Monhtly rental cost (PLN)', ylabel='City district', title='Price distribution in districts')
plt.show()

# %%
ranks = dataset.groupby('location')['price_m2'].median().sort_values()[::-1].index
ax = sns.boxplot(data=dataset, y='location',x='price_m2',fliersize=2,order=ranks)
ax.set(xlabel='Monthly rental cost (PLN per 1 m^2)', ylabel='City district', 
       title='Price distribution in districts - one square meter')
plt.show()

# %%
ax = sns.boxplot(data=dataset, y='n_rooms',x='price',fliersize=2,orient='h')
ax.set(xlabel='Price for monthly rent in PLN', ylabel='Number of rooms', title='Price distribution per number of rooms')
plt.show()

# %%
ax = sns.boxplot(data=dataset,y='advertiser',x='price',orient='h')
ax.set(xlabel='Price for monthly rent in PLN', ylabel='Advertiser type', title='Price distribution per advertiser type')
plt.show()

# %% [markdown]
# # Two-room apartments analysis

# %%
two_room = dataset[(dataset['n_rooms']==2.0) & (dataset['price']<6000.0)]

# %%
two_room.describe()
# Out:
#               price  n_rooms        n_bath       size_m2      price_m2
# count  83481.000000  83481.0  83481.000000  83481.000000  83481.000000
# mean    2784.634288      2.0      1.013284     50.055162     56.541361
# std      605.863076      0.0      0.116153      9.473433     11.857866
# min      350.000000      2.0      1.000000     11.000000      7.600000
# 25%     2400.000000      2.0      1.000000     43.000000     48.076923
# 50%     2700.000000      2.0      1.000000     50.000000     55.555556
# 75%     3000.000000      2.0      1.000000     55.000000     63.888889
# max     5990.000000      2.0      4.000000    250.000000    131.428571

# %%
plt.figure(figsize=(10,6))
ranks = two_room.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=two_room, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel="Total price (PLN)", ylabel='City district', title='Price distribution in districts (two-room flats)')
plt.show()

# %%
plt.figure(figsize=(10,6))
ranks = two_room.groupby('location')['price_m2'].median().sort_values()[::-1].index
ax = sns.boxplot(data=two_room, y='location',x='price_m2',fliersize=2, order=ranks)
ax.set(xlabel="Price (PLN per 1 m^2)", ylabel='City district', 
       title='Price distribution in districts - one square meter (two-room flats)')
plt.show()

# %% [markdown]
# # Three-room apartments analysis

# %%
three_room = dataset[(dataset['n_rooms']==3.0) & (dataset['price']<10000.00)]

# %%
three_room.describe()
# Out:
#               price  n_rooms        n_bath       size_m2      price_m2
# count  40087.000000  40087.0  40087.000000  40087.000000  40087.000000
# mean    3941.689001      3.0      1.121236     75.659391     52.313878
# std     1366.574413      0.0      0.335600     18.338817     12.969971
# min      388.000000      3.0      1.000000     10.000000      6.258065
# 25%     3000.000000      3.0      1.000000     63.000000     43.333333
# 50%     3600.000000      3.0      1.000000     72.000000     50.943396
# 75%     4500.000000      3.0      1.000000     85.000000     59.450009
# max     9990.000000      3.0      4.000000    185.000000    125.333333

# %%
plt.figure(figsize=(10,6))
ranks = three_room.groupby('location')['price'].median().sort_values()[::-1].index
ax = sns.boxplot(data=three_room, y='location',x='price',fliersize=2,order=ranks)
ax.set(xlabel="Total price (PLN)", ylabel='City district', title='Price distribution in districts (three-room flats)')
plt.show()

# %% [markdown]
# ## Linear regression model

# %%
district_data = dataset[dataset['location'] == 'Mokotow']

# %%
district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]

# %%
district_data.corr()
# Out:
#             price   n_rooms   size_m2    n_bath
# price    1.000000  0.719881  0.882781  0.181071
# n_rooms  0.719881  1.000000  0.812866  0.243169
# size_m2  0.882781  0.812866  1.000000  0.251386
# n_bath   0.181071  0.243169  0.251386  1.000000

# %%
parking = pd.get_dummies(district_data['parking'],prefix='parking')
model_dataset = pd.concat([district_data,parking],axis=1)
model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
model_dataset.describe()
# Out:
#               price       n_rooms       size_m2        n_bath  \
# count  42142.000000  42142.000000  42142.000000  42142.000000
# mean    3559.623060      2.374187     63.102938      1.061340
# std     1810.997985      0.813008     29.183703      0.252391
# min      350.000000      1.000000      6.000000      1.000000
# 25%     2600.000000      2.000000     46.000000      1.000000
# 50%     3000.000000      2.000000     54.000000      1.000000
# 75%     3800.000000      3.000000     70.000000      1.000000
# max    14500.000000      6.000000    290.000000      4.000000
#
#        parking_basement  parking_garage  parking_street
# count      42142.000000    42142.000000    42142.000000
# mean           0.106355        0.226662        0.093137
# std            0.308295        0.418677        0.290628
# min            0.000000        0.000000        0.000000
# 25%            0.000000        0.000000        0.000000
# 50%            0.000000        0.000000        0.000000
# 75%            0.000000        0.000000        0.000000
# max            1.000000        1.000000        1.000000

# %%
X = model_dataset.drop('price',axis=1)
y = model_dataset['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
coeffs = pd.DataFrame(data=lm.coef_,index=X.columns, columns=['Coefficient'])
coeffs.sort_values(by='Coefficient',inplace=True)

# %%
plt.figure(figsize=(3,3))
sns.barplot(data=coeffs.transpose(),orient='h',color='lightblue')
plt.show()

# %%
pred = lm.predict(X_test)

# %%
lm.score(X_test,y_test)
# Out:
# 0.78481753815636435

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=42,
#            verbose=0, warm_start=False)

# %%
print('Random Forest R squared": %.4f' % forest_reg.score(X_test, y_test))
# Out:
# Random Forest R squared": 0.8763

# %% [markdown]
# ## Models for all districts

# %% [markdown]
# Linear regression:

# %%
districts = list(dataset['location'].unique())

# %%
districts
# Out:
# ['Wola',
#  'Mokotow',
#  'Srodmiescie',
#  'Wilanow',
#  'Zoliborz',
#  'Ursynow',
#  'Praga Poludnie',
#  'Ochota',
#  'Bialoleka',
#  'Praga Polnoc',
#  'Ursus',
#  'Bielany',
#  'Wawer',
#  'Bemowo',
#  'Wlochy',
#  'Targowek',
#  'Wesola',
#  'Rembertow']

# %%
r2_dict = dict()
model_dict = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    lm = LinearRegression()
    lm.fit(X_train,y_train)
    coeffs = pd.DataFrame(data=lm.coef_,index=X.columns, columns=['Coefficient'])
    coeffs.sort_values(by='Coefficient',inplace=True)
    r2_dict[district] = lm.score(X_test,y_test)
    model_dict[district] = coeffs

# %%
r2 = pd.DataFrame(pd.Series(r2_dict),columns=['R^2 Score'])
r2.sort_values(by='R^2 Score',ascending=False)
# Out:
#                 R^2 Score
# Wilanow          0.831894
# Praga Poludnie   0.787963
# Mokotow          0.784741
# Ochota           0.721473
# Ursynow          0.692356
# Wesola           0.682211
# Srodmiescie      0.674256
# Ursus            0.673275
# Bemowo           0.659751
# Bialoleka        0.656978
# Zoliborz         0.650191
# Targowek         0.647800
# Praga Polnoc     0.647060
# Wawer            0.637361
# Wlochy           0.610266
# Wola             0.571552
# Bielany          0.545212
# Rembertow        0.149511

# %%
regression_parameters = pd.DataFrame(pd.Series(model_dict))
regression_parameters.loc['Bemowo'][0]
# Out:
#                   Coefficient
# parking_street    -194.382443
# parking_garage      -6.010710
# parking_basement     9.409062
# size_m2             28.281337
# n_bath              29.784653
# n_rooms            105.015639

# %% [markdown]
# Random forest regression:

# %%
r2_dict_rf = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    forest_reg = RandomForestRegressor()
    forest_reg.fit(X_train, y_train)
    r2_dict_rf[district] = forest_reg.score(X_test,y_test)

# %%
r2_rf = pd.DataFrame(pd.Series(r2_dict_rf),columns=['R^2 Score_random_forest'])
r2_rf.sort_values(by='R^2 Score_random_forest',ascending=False)
# Out:
#                 R^2 Score_random_forest
# Wilanow                        0.951217
# Bialoleka                      0.915447
# Praga Polnoc                   0.902006
# Praga Poludnie                 0.885447
# Ochota                         0.884566
# Mokotow                        0.875434
# Zoliborz                       0.868066
# Targowek                       0.852829
# Wawer                          0.846304
# Wlochy                         0.842367
# Bielany                        0.833965
# Ursynow                        0.823505
# Bemowo                         0.812188
# Wola                           0.810011
# Srodmiescie                    0.798111
# Ursus                          0.787107
# Wesola                         0.710819
# Rembertow                     -0.071982

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
r2_dict_extra_tree = dict()

# %%
for district in districts:
    district_data = dataset[dataset['location'] == district]
    district_data = district_data[['price','n_rooms','size_m2','parking','n_bath']]
    parking = pd.get_dummies(district_data['parking'],prefix='parking')
    model_dataset = pd.concat([district_data,parking],axis=1)
    model_dataset.drop(['parking','parking_no'],axis=1,inplace=True)
    X = model_dataset.drop('price',axis=1)
    y = model_dataset['price']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    forest_reg_e = ExtraTreesRegressor(n_estimators=1000)
    forest_reg_e.fit(X_train, y_train)
    r2_dict_extra_tree[district] = forest_reg_e.score(X_test,y_test)

# %%
r2_rf_extra = pd.DataFrame(pd.Series(r2_dict_extra_tree),columns=['R^2 Score_extra_trees'])
r2_rf_extra.sort_values(by='R^2 Score_extra_trees',ascending=False)
# Out:
#                 R^2 Score_extra_trees
# Wilanow                      0.951759
# Bialoleka                    0.907424
# Ochota                       0.901274
# Praga Poludnie               0.896516
# Mokotow                      0.881379
# Zoliborz                     0.881195
# Praga Polnoc                 0.880486
# Bemowo                       0.830028
# Ursus                        0.828542
# Targowek                     0.823461
# Ursynow                      0.817213
# Bielany                      0.811760
# Wola                         0.803149
# Srodmiescie                  0.800893
# Wawer                        0.768885
# Wlochy                       0.728625
# Wesola                       0.536988
# Rembertow                   -0.608553
